# %%
arr = ["gato", 1, 10, 20]

# %%
"gato" in arr
# Out:
# True

# %%
10 in arr
# Out:
# True

# %%
max(arr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8a15c9db5e17> in <module>()
# ----> 1 max(arr)
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
max([1, 10, 500, 100])
# Out:
# 500

# %%
min([-10, -20, 30, 50])
# Out:
# -20

# %%
len([1, 1, 1])
# Out:
# 3

# %%
arr.append("leão")

# %%
arr
# Out:
# ['gato', 1, 10, 20, 'leão']

# %%
arr.extend(["cobra", 123])

# %%
arr
# Out:
# ['gato', 1, 10, 20, 'leão', 'cobra', 123]

# %%
arr.count('gato')
# Out:
# 1

# %%
arr.append(["teste", 1])
arr
# Out:
# ['gato', 1, 10, 20, 'leão', 'cobra', 123, ['teste', 1]]

# %%
arr.count(['teste', 1])
# Out:
# 1

# %%
['teste', 1] in arr
# Out:
# True

# %%
arr.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-4765ac5333f7> in <module>()
# ----> 1 arr.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
lista = [4, 6, 3, 2, 10]
lista.sort()

# %%
lista
# Out:
# [2, 3, 4, 6, 10]

# %%
tp = (1, 5, 10 , 20)

# %%
tp[0:3]
# Out:
# (1, 5, 10)

# %%
5 in tp
# Out:
# True

# %%
dic = {"teste": "testeValue"}

# %%
dic.keys()
# Out:
# dict_keys(['teste'])

# %%
dic.values()
# Out:
# dict_values(['testeValue'])
