# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
# Upload files
from google.colab import files
arq= files.upload()
# Out:
#      <input type="file" id="files-7aaf1829-2643-4680-bf04-51144fb87571" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7aaf1829-2643-4680-bf04-51144fb87571">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdventureWorks.xlsx to AdventureWorks.xlsx

# %%
df = pd.read_excel('AdventureWorks.xlsx')

# Visualizar 5 primeiras linhas
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
# Quantidade de linhas e colunas
df.shape
# Out:
# (904, 16)

# %%
# Verificando tipos de dados
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
# Qual a receita total?
df['Valor Venda'].sum()
# Out:
# 5984606.1426

# %%
# Qual o custo total
df['custo'] = df['Custo Unitário'].mul(df['Quantidade'])
df.head(1)
round(df['custo'].sum(), 2)
# Out:
# 2486783.05

# %%
# Qual e o lucro total?
df['lucro'] = df['Valor Venda'] - df['custo']
round(df['lucro'].sum(), 2)
# Out:
# 3497823.09

# %%
# Media do tempo de envio por marca
df['tempo_envio'] = (df['Data Envio'] - df['Data Venda']).dt.days
df.groupby('Marca')['tempo_envio'].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: tempo_envio, dtype: float64

# %%
# Verificando se temos valores ausentes
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# custo             0
# lucro             0
# tempo_envio       0
# dtype: int64

# %%
# Qual é o lucro anual por marca
pd.options.display.float_format = '{:20,.2f}'.format
df.groupby([df['Data Venda'].dt.year, 'Marca'])['lucro'].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: lucro, dtype: float64

# %%
# Resetando index
lucro_ano = df.groupby([df['Data Venda'].dt.year, 'Marca'])['lucro'].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
# Unidades vendidas por produto
unidades_vendidas_por_produto= df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False)
unidades_vendidas_por_produto
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
# Grafico Unidades vendias por produto
unidades_vendidas_por_produto.plot.barh(title='Total produtos vendidos')
plt.xlabel('Total')
plt.ylabel('Produto');

# %%
# Lucro por ano
df.groupby(df['Data Venda'].dt.year)['lucro'].sum().plot.bar(title= 'Lucro x Ano')
plt.xlabel('Ano')
plt.ylabel('Lucro');

# %%
# Vendas de 2009
df_2009 = df[df['Data Venda'].dt.year == 2009]
df_2009.head()
# Out:
#    Data Venda Data Envio  ...                lucro  tempo_envio
# 11 2009-05-02 2009-05-14  ...             2,456.52           12
# 12 2009-05-16 2009-05-27  ...             2,456.52           11
# 13 2009-05-31 2009-06-12  ...             2,456.52           12
# 14 2009-06-28 2009-07-11  ...             2,456.52           13
# 15 2009-07-08 2009-07-12  ...             2,456.52            4
#
# [5 rows x 19 columns]

# %%
# Lucro por mês de 2009
df_2009.groupby(df['Data Venda'].dt.month)['lucro'].sum().plot(title='Lucro x Mês')
plt.xlabel('Mês')
plt.ylabel('Lucro');

# %%
# Lucro por marca em 2009
df_2009.groupby('Marca')['lucro'].sum().plot.bar(title='Lucro x Marca')
plt.xlabel('Marca')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
# Lucro por classe
df_2009.groupby('Classe')['lucro'].sum().plot.bar(title='Lucro x Classe')
plt.xlabel('Classe')
plt.ylabel('Lucro')
plt.xticks(rotation='horizontal');

# %%
df['tempo_envio'].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: tempo_envio, dtype: float64

# %%
# Boxplot
plt.boxplot(df['tempo_envio']);

# %%
# Histograma
plt.hist(df['tempo_envio']);

# %%
# Tempo mínimo de envio
df['tempo_envio'].min()
# Out:
# 4

# %%
# Tempo máximo de envio
df['tempo_envio'].max()
# Out:
# 20

# %%
# Identificando o Outilier
df[df['tempo_envio'] == 20]
# Out:
#   Data Venda Data Envio  ...                lucro  tempo_envio
# 0 2008-05-09 2008-05-29  ...             2,456.52           20
#
# [1 rows x 19 columns]
